# %%
import pandas as pd
import numpy as np
from IPython.display import display
import scipy.stats as st
import statsmodels.api as sm
import matplotlib.pyplot as plt

import statsmodels.stats.api as sms
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve as roc_auc
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier, Pool, cv

from sklearn.metrics import auc
from catboost.utils import get_roc_curve

# %% [markdown]
# # Оглавление <a id='root'>
# * [Задание 1](#1)
#     * [Задача 1](#1.1)
#     * [Задача 2](#1.2)
# * [Задание 2](#2)
#     * [Задача 1](#2.1)
#     * [Задача 2](#2.2)
#     * [Задача 3](#2.3)
#     * [Задача 4](#2.4)
# * [Задание 3](#3)
#     * [Задача 1](#3.1)
# * [Задание 4](#4)
#     * [Обработка пропусков данных](#4.0)
#     * [Задача 1](#4.1)
#         * [Модель 1](#4.1.1)
#         * [Модель 2](#4.1.2)
#         * [Вывод](#4.1.3)

# %% [markdown]
# # Задание 1 <a id='1'>

# %%
df = pd.read_excel('3_task_моделирование.xlsx', sheet_name ='Задание 1', usecols="A:B", names=['observation','time'])
df.observation=df.observation.astype('int')
df.set_index('observation', inplace=True)
display(df.head())
# Out:
#              time
# observation
# 1            27.0
# 2            24.0
# 3            17.0
# 4            19.0
# 5            30.0

# %% [markdown]
# ## Задача 1 <a id='1.1'>

# %% [markdown]
# В соответствии со стандартами обслуживания  клиентов среднее время ожидания клиентом ответа оператора не должно превышать 20 секунд. Для проверки качества обслуживания клиентов была проанализирована выборка из 30 звонков. На основе представленных данных можно ли утверждать, что  среднее время ожидания ответа оператора возросло и составляет более 20 секунд (допуская, что данные в генеральной совокупности имеют нормальное распределение).

# %% [markdown]
# посмотрим на инфу о датафрейме

# %%
display(df.describe())
display(df.info())
display(df.isna().sum())
# Out:
#             time
# count  30.000000
# mean   22.833333
# std     6.475861
# min     7.000000
# 25%    19.000000
# 50%    24.000000
# 75%    27.750000
# max    36.000000
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 1 to 30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    30 non-null     float64
# dtypes: float64(1)
# memory usage: 480.0 bytes
# None
# time    0
# dtype: int64

# %% [markdown]
# Все супер, пропусков нет, всего есть 30 наблюдений, среднее и медианное значения не совсем совпадают, поэтому вглянем на распределение. Есть ощущение, что не совсем нормальное

# %%
sns.histplot(data = df, bins=10)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Так и есть, не совсем нормальное. Плюс у нас менее 36 наблюдений, поэтому сравнивать будем через t-распределение. Построим 95% доверительный интервал оценки среднего и проверим, попадает ли наш норматив в доверительный интервал оценки среднего.

# %%
st.t.interval(0.95, df.shape[0]-1, loc=df.time.mean(), scale=st.sem(df.time))
# Out:
# (20.41520692452492, 25.251459742141744)

# %%
st.t.interval(0.99, df.shape[0]-1, loc=df.time.mean(), scale=st.sem(df.time))
# Out:
# (19.57438900296361, 26.092277663703054)

# %% [markdown]
# В целом, с ростом числа наблюдений, t-распределение стремится к нормальному, так что данный способ проверки имеет место быть. Мы получили, что доверительный доверительный интервал среднего значения генеральной совокупности больше 20 секунд (в предположении 95% доверительного интервала). Однако, подтвердить факт того, что среднее время "возрасло", в текущей постановке задачи, мы не можем, потому как не знаем какое оно было. Вполне может быть, что стандарт был изначально завышен относительно реальных данных, либо установлен на основании 99% доверительного интервала (в этом случает доверительный интервал шире и нижняя граница меньше 20 секунд).

# %% [markdown]
# [К оглавлению](#root)

# %% [markdown]
# ## Задача 2 <a id='1.2'>

# %% [markdown]
# Предположим, что необходимо оценить текущее среднее значение времени ответа оператора с точностью +/- 2 секунды и построить 95% доверительный интервал для этой величины. Определите, требуемый для этого объем выборки.

# %% [markdown]
# $n=(\frac{Z \sigma}{e})^2$ где $e$-приемлемая ошибка выборочного исследования $\sigma$-стандартное отклонение генеральной совокупности $Z$- z-значение требуемого доверительного уровня
#
# В нашем случае $e=2$, $Z=1.96$, а $\sigma=\sqrt{\frac{\sum({x-\hat{x}})^2}{n-1}}$ нужно рассчитать

# %%
sigma = df.time.std(ddof=1)
Z = 1.96
e = 2

n = ((Z*sigma)/e)**2
print(f'требуемый объем выборки для исследования: {n:.0f} наблюдений')
# Out:
# требуемый объем выборки для исследования: 40 наблюдений

# %% [markdown]
# [К оглавлению](#root)

# %% [markdown]
# ## Задание 2 <a id='2'>

# %%
df = pd.read_excel('3_task_моделирование.xlsx', sheet_name ='Задание 2', usecols="A:B", names=['expenses','sales'])

display(df.head())
display(df.info())
display(df.describe())
# Out:
#    expenses  sales
# 0     230.1   22.1
# 1      44.5   10.4
# 2      17.2    9.3
# 3     151.5   18.5
# 4     180.8   12.9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   expenses  200 non-null    float64
#  1   sales     200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB
# None
#          expenses       sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %% [markdown]
# ### Задача 1 <a id='2.1'>

# %% [markdown]
# Постройте линейную регрессионную модель, позволяющую предсказывать объем продаж в регионе в зависимости от расходов на рекламу. Напишите уравнение регресссии.

# %% [markdown]
# в первую очередь посмотрим на график зависимости продаж от затрат.

# %%
plt.scatter( df.expenses, df.sales)
plt.xlabel('Затраты (тыс. руб)')
plt.ylabel('Продажи (тыс. шт)')
# Out:
# Text(0, 0.5, 'Продажи (тыс. шт)')

# %% [markdown]
# Тут надо вспомнить условия применения линейной регрессии:
# - Линейная взаимосвязь переменных
# - Нормальность распределения остатков
# - Гомоскедастичность
#
# Вот с гомоскедастичностью и нормальностью распределения остатков, для нашей линейной регрессии - будут проблемы, потому как график у нас представим ввиде факела. Попробуем исправить это. Поскольку график похож на экспоненциальный - логорифмируем и посмотрим на график

# %%
plt.scatter(np.log(df.expenses), np.log(df.sales))

# %% [markdown]
# вот так уже лучше. Мы сохранили линейность, при этом приблизились к гомоскедастичности и нормальности распределения (хотя про нормальность - вопрос, скорее всего в результате оно будет скошено).
# Теперь можно попробовать обучить модельку и вывести уравнение регрессии.

# %%
target = df.drop(columns=['expenses'])
features = df.drop(columns=['sales'])

X = np.log(features)
y = np.log(target)

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.742
# Model:                            OLS   Adj. R-squared:                  0.741
# Method:                 Least Squares   F-statistic:                     569.8
# Date:                Sun, 19 Jun 2022   Prob (F-statistic):           3.51e-60
# Time:                        20:43:27   Log-Likelihood:                 28.454
# No. Observations:                 200   AIC:                            -52.91
# Df Residuals:                     198   BIC:                            -46.31
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9052      0.071     12.737      0.000       0.765       1.045
# expenses       0.3550      0.015     23.871      0.000       0.326       0.384
# ==============================================================================
# Omnibus:                       32.754   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.599
# Skew:                          -0.117   Prob(JB):                       0.0136
# Kurtosis:                       2.011   Cond. No.                         23.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
intercept = est2.params['const']
alpha = est2.params['expenses']

if alpha>=0: 
    sign = '+' 
else:
    sign = ''
print(f'уравнение регрессии имеет вид: log({target.columns[0]})={intercept}{sign}{alpha}*log({features.columns[0]})')
# Out:
# уравнение регрессии имеет вид: log(sales)=0.9052454593989981+0.35503573348588763*log(expenses)

# %% [markdown]
# В целом, наша модель не лишена смысла: с ростом количествва затрат на маркетинг - растет количество продаж
#
# Посмотрим на распределение остатоков модели

# %%
y_pred = intercept+alpha*np.log(features).values
redusals = np.log(target.values)-y_pred


fig, ax = plt.subplots(1,2, figsize=(20,7), gridspec_kw={'width_ratios': [1, 2]})
fig.suptitle('Остатки')
ax[0].scatter(y =redusals, x=y_pred)
ax[1].hist(redusals[:,0])



plt.show()

# %% [markdown]
# в целом, не сказать что наши остатки распределены нормально, как и предполагалось присутствует и скошенность. В целом, я бы не рекомендовал использовать такую модель, потому как не выполняется свойство нормальности и гомоскедастичности распределения остатков. Но задание есть задание.

# %% [markdown]
# [К оглалению](#root)

# %% [markdown]
# ### Задача 2 <a id='2.2'>

# %% [markdown]
# Дайте графическую интерпритацию, полученных результатов (отобразите на одном графике уравнение регрессии и наблюдения, представленные в наборе данных)

# %%
pred = [np.exp(i) for i in y_pred]


data = []
for i in range(0, len(pred)):
    arr = [pred[i],target.values[i][0],features.values[i][0]]
    data.append(arr)

res = pd.DataFrame(data,  columns=['yhat','target','features'])

plt.scatter( res.features, res.target, color='blue', label='real sales')
plt.plot( res.features, res.yhat, color = 'red', label='regression plot')
plt.xlabel('sales')
plt.ylabel('expenses')
plt.legend()
plt.show()

# %% [markdown]
# [К оглалению](#root)

# %% [markdown]
# ### Задача 3 <a id='2.3'>

# %% [markdown]
# Предскажите объем продаж при расходах на рекламу в 121 тыс. руб.

# %% [markdown]
# Поскольку мы обучали модель на логорифмированных данных, то и для предсказаний, вместо того, чтобы передавать 121 тысячу, мы передадим логарифм от 121 тысячи (обучались мы на данных, где затраты в тысячах. Т.е. вместо 121 000 предаем просто 121), а само предсказание не забудем перевести в обратную сторону.

# %%
spendings = 121
expected_sales = np.exp(intercept+alpha*np.log(spendings))

print(f'при затратах в {spendings} тысячу на маркетинг, модель прогнозирует {expected_sales:.2f} тысяч едениц продаж')
# Out:
# при затратах в 121 тысячу на маркетинг, модель прогнозирует 13.57 тысяч едениц продаж

# %% [markdown]
# [К оглалению](#root)

# %% [markdown]
# ### Задача 4 <a id='2.4'>

# %% [markdown]
# Сделайте вывод о статистической значимости коэффициентов линейной регрессии.

# %%
if est2.pvalues[1]<0.05:
    msg = f'''
    На основании того факта, что согласно t-тесту, для коэффициента при независимой переменной мы получили оценку p-value меньше 0.05 (у нас она ~{est2.pvalues[1]:.2f}) 
    мы можем отклонить нулевую гипотезу о том, что у нас отсутсвует линейный тренд в данных, а значит наша модель нашла взаимосвязи между зависимой и независимой переменными. 
    И все это значит, что взаимосвязь между переменными - статистически значима (на 95% уровне значимости).
    '''
else:
    msg =f'''
    К сожалению, построенная нами модель не смогла найти статистически значимую (на 95% уровне значимости) взаимосвязь между переменными.
    '''

print(f'''
Полученная модель объясняет {est2.rsquared_adj:.2%} вариации зависимой перменной
Это не много и не мало. Скорее всего, что логично, наша модель не учитывает другие значимые факторы. Например это может быть работа колл-центра.
'''+msg)
# Out:
# Полученная модель объясняет 74.08% вариации зависимой перменной
# Это не много и не мало. Скорее всего, что логично, наша модель не учитывает другие значимые факторы. Например это может быть работа колл-центра.
#
#     На основании того факта, что согласно t-тесту, для коэффициента при независимой переменной мы получили оценку p-value меньше 0.05 (у нас она ~0.00)
#     мы можем отклонить нулевую гипотезу о том, что у нас отсутсвует линейный тренд в данных, а значит наша модель нашла взаимосвязи между зависимой и независимой переменными.
#     И все это значит, что взаимосвязь между переменными - статистически значима (на 95% уровне значимости).

# %% [markdown]
# [К оглалению](#root)

# %% [markdown]
# ## Задание 3 <a id='3'>

# %% [markdown]
# Имеются две модели, предсказывающие вероятность дефолта клиента и фактические наблюдения данного события (1 - факт дефолта клиента, 0 - отсутствие  дефолта клиента)

# %%
df = pd.read_excel('3_task_моделирование.xlsx', sheet_name ='Задание 3', usecols="A:C", names=['real','model_1','model_2'])

display(df.head())
display(df.info())
# Out:
#    real   model_1   model_2
# 0   0.0  0.409821  0.526825
# 1   0.0  0.576899  0.606770
# 2   0.0  0.470889  0.499478
# 3   0.0  0.256406  0.334723
# 4   0.0  0.324825  0.403021
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   real     311 non-null    float64
#  1   model_1  311 non-null    float64
#  2   model_2  311 non-null    float64
# dtypes: float64(3)
# memory usage: 7.4 KB
# None

# %% [markdown]
# ### Задача 1 <a id='3.1'>

# %% [markdown]
# Предложите метрику качества, позволяющую сравнить эти модели и выбрать наилучшую на основе представленных данных.  Также желательно предоставить графическую интерпретацию полученных результатов

# %% [markdown]
# Посмотрим на баланс классов

# %%
not_defolt = df[df.real==0].shape[0]
defolt = df.shape[0]-not_defolt
print(f'всего клиентов без дефолта: {not_defolt} \n всего клиентов с дефолтом: {defolt}')
# Out:
# всего клиентов без дефолта: 157
#  всего клиентов с дефолтом: 154

# %% [markdown]
# Отлично, дисбаланса классов у нас не наблюдается, значит можно как минимум использовать метрику accuracy. Но есть одно "но" - модели прогнозируют не четкие метки класса, а вероятность отнести того или иного клиента к одному из двух классов. Вполне понятно почему это сделано - чтобы можно было более сегментировать тех, у кого возможен дефолт. В условиях, когда ресурсы ограничены (а количество специалистов всегда конечно) - целесообразно в первую очередь работать с теми клиентами, риск дефолта у которых выше, а значит, нужно как-то более детально сегментировать клиентов.
#
# Так или иначе - accuracy нам не очень подходит (как в прочем метрики полноты, точности и их комбинацию - метрика f1) просто потому, что мы не можем их расчитать, когда у нас целевая переменная бинарна, а предсказания - непрерывны. Даже, если нам это удастся рассчитать эти метрики, например мы зададим какой-то порог отнесения к классу (threshhold), все равно остается риск, что при повторном обучении (например после поступления новых данных ввиду резкого изменения внешней ситуации а-ля "а что произошло?" в марте 2022г.), в обучающую выборку могут попасть исключительно объекты одного из классов. В этом случае расчитать precision ($\frac{TP}{TP+FP}$) может быть проблематично (положительные объекты ведь отстутствуют), а нам, все же, хочется, чтобы наша система хорошо работала и таких условиях.
#
# Итого, что мы имеем:
# - мы хотим, чтобы наша метрика работала даже на несбалансированных данных
# - мы хотим не быть привязанными к threshold (т.е. к конкретному порогу начиная с которого мы помечаем объект, как относящийся к классу)
#
# В целом, под эти требования подходи AUC-ROC ( площадь под кривой в координатах ($FPR=\frac{FP}{N}$ ; $TPR=\frac{TP}{P}$ ))

# %%
fpr_1, tpr_1, thresholds_1 = roc_auc(df.real, df.model_1)

fpr_2, tpr_2, thresholds_2 = roc_auc(df.real, df.model_2)


fig, ax = plt.subplots(figsize=(20,7))
fig.suptitle('ROC_AUC')
ax.plot(tpr_1, fpr_1, label='model_1')
ax.plot(tpr_2, fpr_2, label='model_2')
ax.plot([[0],[1]],[[0],[1]], label='random_model')
plt.legend()
plt.show()

# %% [markdown]
# [К оглалению](#root)

# %% [markdown]
# ## Задание 4 <a id='4'>

# %% [markdown]
# Данные:
# Предложенная таблица содержит данные по 5000 клиентов:
# - num - Порядковый номер клиента
# - predictor1-5 - Переменные (предикторы) по которым необходимо построить модель. Все переменные являются количественными.
# - target - Целевая бинарная переменная, обозначающая факт дефолта клиента
#
#
# N.B.: predictor 3 содержит пропущенные значения, выбор метода их обработки остается за соискателем.

# %%
df = pd.read_excel('3_task_моделирование.xlsx', sheet_name ='Задание 4', usecols="A:g", names=['num','predictor_1','predictor_2','predictor_3','predictor_4','predictor_5','target'])

display(df.head())
display(df.info())
display(df.isna().sum())
# Out:
#    num  predictor_1  predictor_2  predictor_3  predictor_4  predictor_5  \
# 0  1.0      12423.0        710.0        441.5          5.0       4631.0
# 1  2.0      13983.0       1106.0          NaN          3.0       4256.0
# 2  3.0      15520.0       1276.0        391.5          1.0       4397.0
# 3  4.0      29535.0       1106.0          NaN          1.0       3772.0
# 4  5.0      26154.0        976.0        315.0          5.0       2445.0
#
#    target
# 0     1.0
# 1     1.0
# 2     0.0
# 3     1.0
# 4     1.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   num          10000 non-null  float64
#  1   predictor_1  10000 non-null  float64
#  2   predictor_2  10000 non-null  float64
#  3   predictor_3  8087 non-null   float64
#  4   predictor_4  10000 non-null  float64
#  5   predictor_5  10000 non-null  float64
#  6   target       10000 non-null  float64
# dtypes: float64(7)
# memory usage: 547.0 KB
# None
# num               0
# predictor_1       0
# predictor_2       0
# predictor_3    1913
# predictor_4       0
# predictor_5       0
# target            0
# dtype: int64

# %% [markdown]
# Обработаем пропуски <a id='4.0'></a>.
# Для этого у нас есть четыре основных пути:
# - востановить пропуски на основании зависимостей с другими данными;
# - заполнить средним или медианным значением;
# - пометить как пропущенные и отпустить ситуацию;
# - удалить колонки с пропущенными значениями;
# - удалить строки с пропущенными значениями.
#
#
# Пятый путь нам не по-карману, удалить 20% датасета - действие сомнительной адекватности. Поэтому, попробуем по порядку первые 2 метода и, если ничего толкового не получится - применим третий или четвертый (если нет корреляции с зависимой переменной - можно и удалить столбец).
#
# Первый метод подразумевает востановление данных на основе регрессии, и позволяет получать правдоподобное заполнение пропусков. Но тут есть проблема, а именно: реальные данные зачастую подразумевают некоторый разброс значений, а в этом мметоде мы лишаемся этой вариативности, и, как следствие, корреляция между "востанавливаемым" и остальными признаками искусственно усиливается. С ростом вариации значений признака пропуски которого мы заполняем, и/или процента пропущенных строк - метод становится все хуже и хуже для конечного результата.
#
# Мы выяснили, что у нас есть 20% пропусков. Посмотрим, может быть вариативность признака не такая большая.

# %%
df.predictor_3.unique()
# Out:
# array([441.5,   nan, 391.5, 315. , 377. , 380. , 397. , 416. , 277.5,
#        384.5, 445.5, 364.5, 330.5, 169. , 325. , 401. , 403.5, 300.5,
#        419. , 304. , 422. , 303.5, 380.5, 307.5, 383. , 385. , 359. ,
#        347.5, 336. , 401.5, 376.5, 328. , 417. , 216.5, 377.5, 422.5,
#        379.5, 304.5, 406. , 371. , 424.5, 277. , 362.5, 224.5, 357. ,
#        382. , 400.5, 255. , 316. , 281.5, 400. , 326.5, 116.5, 434. ,
#        309.5, 447. , 333.5, 444. , 353. , 465. , 409. , 452.5, 338.5,
#        217.5, 385.5, 394.5, 309. , 339. , 310. , 432. , 449. , 473. ,
#        404. , 473.5, 432.5, 261.5, 464. , 418.5, 297.5, 317.5, 451. ,
#        355.5, 475.5, 343.5, 357.5, 479. , 375.5, 417.5, 438. , 368.5,
#        476. , 423. , 426. , 271. , 442. , 430. , 427. , 232.5, 351. ,
#        352.5, 433. , 434.5, 430.5, 406.5, 219. , 288.5, 469.5, 199.5,
#        374. , 265.5, 425. , 293.5, 344. , 462.5, 372. , 248. , 350.5,
#        464.5, 233. , 291.5, 462. , 398.5, 360. , 497.5, 485.5, 425.5,
#        327. , 367. , 347. , 257. , 423.5, 387.5, 280. , 389. , 211.5,
#        437.5, 447.5, 172.5, 286. , 266.5, 411.5,  62. , 482.5, 410. ,
#        316.5, 132.5, 273. , 416.5, 318. , 472. , 359.5, 376. , 361.5,
#        321.5, 364. , 118.5, 389.5, 239.5, 362. , 270. , 272. , 344.5,
#        285. , 411. , 292. , 435. , 237.5, 330. , 412.5, 405.5, 268.5,
#        326. , 443. , 197. , 413.5, 461.5, 452. , 286.5, 476.5, 320.5,
#        382.5, 341. , 262.5, 352. , 420. , 431.5, 378.5, 429.5, 407.5,
#        308.5, 329. , 456. , 470.5, 280.5, 332.5, 358.5, 239. , 449.5,
#        289. , 274. , 415.5, 256.5, 402. , 448.5, 288. , 283.5, 311.5,
#        495. , 341.5, 483. , 306. , 402.5, 412. , 257.5, 503. , 324.5,
#        291. , 413. , 208.5, 435.5, 348. , 331. , 395.5, 245. , 429. ,
#        415. , 197.5, 450.5, 482. , 264.5, 247. , 387. , 143.5, 370. ,
#        335.5, 409.5, 384. , 247.5, 334. , 250.5, 295.5, 283. , 366. ,
#        234.5, 349.5, 467.5, 299.5, 295. , 484.5, 386. , 446.5, 223.5,
#        421.5, 243. , 296.5, 428.5, 296. , 302. , 396. , 353.5, 390.5,
#        323.5, 251.5, 397.5, 311. , 494. , 334.5, 275. , 350. , 340. ,
#        229.5, 305.5, 229. , 461. , 285.5, 381.5, 186.5, 408. , 497. ,
#        196. , 165. , 403. , 381. , 319. , 306.5, 441. , 378. , 466. ,
#        226.5, 290. , 321. , 160.5, 329.5, 298. , 346.5, 203.5, 254. ,
#        437. , 420.5, 436. , 418. , 228.5, 419.5, 395. , 485. , 271.5,
#        279.5, 370.5, 182.5,  80. , 374.5, 414.5, 439. , 284. , 153.5,
#        293. , 259.5, 373.5, 339.5, 408.5, 317. , 480. , 294.5, 193.5,
#        333. , 361. , 477. , 367.5, 269. , 274.5, 393. , 427.5, 210.5,
#        282. , 236.5, 307. , 379. , 325.5, 301.5, 426.5, 342. , 174. ,
#        356.5, 457. , 135. , 193. , 369.5, 443.5, 244. , 259. , 358. ,
#        276.5, 456.5, 368. , 342.5, 467. , 202.5, 222.5, 258.5, 348.5,
#        458. , 345. , 399.5, 369. , 372.5, 183. , 431. , 458.5, 499.5,
#        227.5, 421. , 383.5, 248.5, 212.5, 386.5, 450. , 238.5, 322.5,
#        438.5, 459.5, 273.5, 345.5, 185. , 230.5, 256. , 290.5, 314. ,
#        356. , 303. , 254.5, 355. , 302.5, 258. , 252. , 392.5, 299. ,
#        388.5, 294. , 505.5, 398. , 399. , 204.5, 365. , 281. , 194. ,
#        390. , 336.5, 375. , 232. , 314.5, 237. , 213. , 279. , 388. ,
#        260. , 436.5, 373. , 191. , 180.5, 322. , 301. , 337. , 255.5,
#        224. , 363. , 129.5, 220. , 451.5, 414. , 250. , 328.5, 263. ,
#        241.5, 262. , 297. , 289.5, 312.5, 245.5, 213.5, 315.5, 235. ,
#        240.5, 393.5, 444.5, 453. , 188.5, 270.5, 394. , 354.5, 214.5,
#        335. , 338. , 392. , 243.5, 214. , 221.5, 466.5, 205.5, 319.5,
#        440. , 226. , 332. , 230. , 157.5, 323. , 157. , 272.5, 500.5,
#        177. , 178. , 287. , 202. , 496. , 455. , 263.5, 190. , 324. ,
#        351.5, 137.5, 327.5, 264. , 218.5, 331.5, 424. , 241. , 349. ,
#        211. , 360.5, 365.5, 404.5, 158.5, 308. , 244.5, 210. , 282.5,
#        407. , 410.5, 253.5, 201.5, 454.5, 481.5, 292.5, 278.5, 454. ,
#        440.5, 242.5, 207.5, 268. , 253. , 246. , 222. , 445. , 235.5,
#        488.5, 238. , 312. , 343. , 190.5, 475. , 492.5, 405. , 287.5,
#        242. , 313. , 185.5, 187.5, 218. , 146. , 189. ,  93.5, 233.5,
#        320. , 300. , 251. , 354. , 278. , 298.5, 439.5, 221. , 109. ,
#        275.5, 195.5, 391. , 215.5, 137. , 346. , 227. , 246.5, 266. ,
#        120.5, 269.5, 145. , 512.5, 176. , 117.5, 276. , 337.5, 154. ,
#        249.5, 192.5, 183.5, 155.5, 184. , 265. , 123. , 267.5, 206. ,
#        181.5, 136. , 231. , 209.5, 363.5, 196.5, 433.5, 310.5, 200. ,
#        158. , 428. , 176.5, 186. , 191.5, 164. , 175. , 471. , 371.5,
#        200.5, 219.5, 249. , 236. , 215. , 182. , 148.5, 225. , 170. ,
#        150. , 164.5, 152.5, 151.5, 318.5, 172. , 198.5, 161.5, 234. ,
#        459. , 198. , 171.5, 207. , 240. , 396.5, 260.5, 149.5, 220.5,
#        284.5, 203. , 156.5, 151. , 171. , 267. , 209. , 225.5, 479.5,
#        188. , 206.5, 189.5, 181. , 228. , 223. , 168.5])

# %% [markdown]
# Мда, вариативность признака большая, процент пропущенных значений большой - нужно пробовать другой методы. Посмотрим на среднее и медианное значения

# %%
df.predictor_3.describe()
# Out:
# count    8087.000000
# mean      368.662174
# std        68.536786
# min        62.000000
# 25%       325.000000
# 50%       377.500000
# 75%       419.000000
# max       512.500000
# Name: predictor_3, dtype: float64

# %% [markdown]
# В целом, у нас близко среднее и медианные значения. Но чем заполнять? Судя по всему - у нас скошенный влево (медиана больше среднего значения). Посмотрим как изменится наше распределение если мы заменим средним или медианой, потому как при использовании этого метода можно лекго, без регистраций и смс, изменить все показатели характеризующие распределение, за исключением того, которым заменяем пропуски.

# %%
plt.hist(df[~df.predictor_3.isna()].predictor_3, bins=30,color='black', alpha=0.2)
plt.hist(df.predictor_3.fillna(df[~df.predictor_3.isna()].predictor_3.median()), bins=30, color='red', alpha=0.3)
plt.hist(df.predictor_3.fillna(df[~df.predictor_3.isna()].predictor_3.mean()), bins=30, color='green', alpha=0.3)
plt.show()

pd.DataFrame(pd.DataFrame(df[~df.predictor_3.isna()].predictor_3.describe()).rename(columns={'predictor_3':'real'})).join(
pd.DataFrame(df.predictor_3.fillna(df[~df.predictor_3.isna()].predictor_3.median()).describe()).rename(columns={'predictor_3':'median'}).join(
    pd.DataFrame(df.predictor_3.fillna(df[~df.predictor_3.isna()].predictor_3.mean()).describe()).rename(columns={'predictor_3':'mean'}))
)
# Out:
#               real       median          mean
# count  8087.000000  10000.00000  10000.000000
# mean    368.662174    370.35285    368.662174
# std      68.536786     61.73082     61.632859
# min      62.000000     62.00000     62.000000
# 25%     325.000000    332.50000    332.500000
# 50%     377.500000    377.50000    368.662174
# 75%     419.000000    407.50000    407.500000
# max     512.500000    512.50000    512.500000

# %% [markdown]
# Вот и ответ. Будем заполнять медианным значением, потому что с случае заполнения средним мы выравниваем наше распределение и среднее начинает почти совпадать с медианой, а нам бы хотелось минимально изменить распределение.

# %%
df.predictor_3.fillna(df[~df.predictor_3.isna()].predictor_3.median(), inplace=True)
df.predictor_3.isna().sum()
# Out:
# 0

# %% [markdown]
# [К оглавлению](#root)

# %% [markdown]
# ### Задача 1 <a id='4.1'>

# %% [markdown]
# Необходимо построить модель, позволяющую предсказывать вероятность дефолта клиента. Предлагается построить 2 конкурирующие модели (например, логистическая регрессия и дерево решений) и произвести выбор наилучшей модели на основе показателя качества AUC ROC (площадь под ROC-кривой).
#
# Необходимо описание (не более 3 страниц) логики построения моделей. Также желательно представить графическую интерпретацию результатов.
#
# При построении моделей разрешается использовать любой статистический пакет\платформу, которым вы владеете.

# %% [markdown]
# Взглянем на данные

# %%
pd.plotting.scatter_matrix(df, figsize=(20,10))
plt.show()

# %% [markdown]
# Отлично, сразу, с ходу, у нас дисбаланс классов, а значит - метрика AUC-ROC тут прямо в тему.
# И, судя по всему, есть корреляция между вторым и третим предиктором. Построим матрицу корреляций и проверим

# %%
# удалим колонку с номером наблюдений, потому что она не несет никакого признака
df.drop(columns='num', inplace=True)
df.corr()
# Out:
#              predictor_1  predictor_2  predictor_3  predictor_4  predictor_5  \
# predictor_1     1.000000     0.024318    -0.000536    -0.012252     0.002024
# predictor_2     0.024318     1.000000     0.422611    -0.255252    -0.028135
# predictor_3    -0.000536     0.422611     1.000000    -0.243960    -0.009769
# predictor_4    -0.012252    -0.255252    -0.243960     1.000000    -0.014792
# predictor_5     0.002024    -0.028135    -0.009769    -0.014792     1.000000
# target         -0.007787    -0.261663    -0.275649     0.213800     0.006806
#
#                target
# predictor_1 -0.007787
# predictor_2 -0.261663
# predictor_3 -0.275649
# predictor_4  0.213800
# predictor_5  0.006806
# target       1.000000

# %% [markdown]
# Интересный результат: predictor_2 действительно сильновато коррелирует с predictor_3, а вот, что более интересно - predictor_1 и perdictor_5 - очень слабо коррелируют с таргетом. В целом, можно их попробовать удалить из признаков и тем самым облегчить сложность модели, а значит и повысить точность.

# %%
new_df = df.drop(columns=['predictor_1','predictor_5']).copy()
display(new_df.corr())
pd.plotting.scatter_matrix(new_df, figsize=(20,10))
plt.show()
# Out:
#              predictor_2  predictor_3  predictor_4    target
# predictor_2     1.000000     0.422611    -0.255252 -0.261663
# predictor_3     0.422611     1.000000    -0.243960 -0.275649
# predictor_4    -0.255252    -0.243960     1.000000  0.213800
# target         -0.261663    -0.275649     0.213800  1.000000

# %% [markdown]
# теперь глаза разбегаются меньше и заметно, что predictor_4  у нас, по своей сути - категориальная переменная, а значит - ее нужно закодировать. Для этого у нас в распоряжении есть минимум 2 метода: LableEncoding и OHE. Первый применяется когда данные упорядочены (например 0-начальная школа, 1-средняя школа, 2-среднее специальное образование и тд) и есть много категорий, а второй - когда данные не упорядочены (например 0-Японимя, 1-Россия, 2-Франция и тд) и данных не много. Мы не знаем, какие именно данные лежат в основе predictor_4, поэтому, если их немного - будем пологать, что это не упорядоченные данные.

# %%
len(df.predictor_4.unique())
# Out:
# 22

# %% [markdown]
# Будем использовать технику OHE. У нас нет задачи, чтобы наша модель была легко интерпретируемой, равно как нам не нужно повторять процедуру кодирования (мы сначала кодируем, а уже потом делим на тренировочную и тестовую выборки), поэтому OHE можно делать просто через get_dummies(), а не через OneHotEncoder() из sklearn.

# %%
new_df.join(
            pd.get_dummies(df.predictor_4, drop_first=True)
        ).drop(columns='predictor_4', inplace=True)

# %% [markdown]
# Теперь поделим на тестовую и валидационные выборки

# %%
target = new_df.target.copy()
features = new_df.drop(columns='target').copy()

print(features.shape, target.shape)

features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2)
print(features_train.shape, target_train.shape)
print(features_test.shape, target_test.shape)
# Out:
# (10000, 3) (10000,)
# (8000, 3) (8000,)
# (2000, 3) (2000,)

# %% [markdown]
# а еще - было бы неплохо стандартизовать переменные. Они у нас разного масштаба.

# %%
scalar = StandardScaler()
scalar.fit(features_train)

features_train_scaler = scalar.transform(features_train)
features_test_scaler = scalar.transform(features_test)

# %% [markdown]
# [К оглавлению](#root)

# %% [markdown]
# #### Модель 1 <a id= '4.1.1'>

# %% [markdown]
# Ну и попробуем обучить модель градиентного бустинга над деревьями, с помощью библиотеки catboost. Для поиска оптимальных параметров, сначала пройдемся широкими шагами random search'ом, а затем более мелкими через grid search. Естественно обучаться будем через кросс-валидацию (ее сделаем на 5 фолдах), а метрикой качества будет площадь под кривой ROC.

# %%
cv_dataset = Pool(data=features_train_scaler,
                  label=target_train,
                  cat_features=None)





model_catboost = CatBoostClassifier(loss_function='Logloss', eval_metric='AUC', random_seed=12345)

grid = {'max_depth':range(1,20,1),
        'learning_rate':np.arange(0.1,1,0.1),
        'iterations':range(1,20,1)
       }

random_search_result = model_catboost.randomized_search(grid, 
                                       X=cv_dataset,
                                       cv=5,
                                       plot=False)

depth_catboost = random_search_result['params']['depth']
iterations_catboost = random_search_result['params']['iterations']
learning_rate_catboost = random_search_result['params']['learning_rate']


print(depth_catboost, iterations_catboost, learning_rate_catboost)
# Out:
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 2.51ms	remaining: 5.03ms
# 1:	test: 0.6767288	best: 0.6767288 (1)	total: 8.27ms	remaining: 4.13ms
# 2:	test: 0.6998362	best: 0.6998362 (2)	total: 13.6ms	remaining: 0us
#
# bestTest = 0.6998362228
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 0:	loss: 0.6998362	best: 0.6998362 (0)	total: 19.3ms	remaining: 174ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 3.93ms	remaining: 11.8ms
# 1:	test: 0.6775681	best: 0.6775681 (1)	total: 11.6ms	remaining: 11.6ms
# 2:	test: 0.7077368	best: 0.7077368 (2)	total: 14ms	remaining: 4.68ms
# 3:	test: 0.7099639	best: 0.7099639 (3)	total: 18.3ms	remaining: 0us
#
# bestTest = 0.7099638772
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 1:	loss: 0.7099639	best: 0.7099639 (1)	total: 39.4ms	remaining: 157ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 4.3ms	remaining: 43ms
# 1:	test: 0.6773245	best: 0.6773245 (1)	total: 9.11ms	remaining: 41ms
# 2:	test: 0.6976308	best: 0.6976308 (2)	total: 11.7ms	remaining: 31.1ms
# 3:	test: 0.6991755	best: 0.6991755 (3)	total: 18.4ms	remaining: 32.2ms
# 4:	test: 0.7009179	best: 0.7009179 (4)	total: 26.2ms	remaining: 31.5ms
# 5:	test: 0.7095225	best: 0.7095225 (5)	total: 29.9ms	remaining: 24.9ms
# 6:	test: 0.7122445	best: 0.7122445 (6)	total: 32.2ms	remaining: 18.4ms
# 7:	test: 0.7088172	best: 0.7122445 (6)	total: 36.8ms	remaining: 13.8ms
# 8:	test: 0.7085965	best: 0.7122445 (6)	total: 40.9ms	remaining: 9.09ms
# 9:	test: 0.7101960	best: 0.7122445 (6)	total: 43.5ms	remaining: 4.35ms
# 10:	test: 0.7105264	best: 0.7122445 (6)	total: 47.9ms	remaining: 0us
#
# bestTest = 0.7122445127
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 2:	loss: 0.7122445	best: 0.7122445 (2)	total: 89.8ms	remaining: 210ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 2.62ms	remaining: 28.8ms
# 1:	test: 0.6773245	best: 0.6773245 (1)	total: 4.89ms	remaining: 24.5ms
# 2:	test: 0.6976308	best: 0.6976308 (2)	total: 7.17ms	remaining: 21.5ms
# 3:	test: 0.6991755	best: 0.6991755 (3)	total: 9.08ms	remaining: 18.2ms
# 4:	test: 0.7009179	best: 0.7009179 (4)	total: 14ms	remaining: 19.6ms
# 5:	test: 0.7095225	best: 0.7095225 (5)	total: 15.9ms	remaining: 15.9ms
# 6:	test: 0.7122445	best: 0.7122445 (6)	total: 19.9ms	remaining: 14.2ms
# 7:	test: 0.7088172	best: 0.7122445 (6)	total: 22.1ms	remaining: 11.1ms
# 8:	test: 0.7085965	best: 0.7122445 (6)	total: 27.7ms	remaining: 9.22ms
# 9:	test: 0.7101960	best: 0.7122445 (6)	total: 33.4ms	remaining: 6.69ms
# 10:	test: 0.7105264	best: 0.7122445 (6)	total: 45.9ms	remaining: 4.17ms
# 11:	test: 0.7109754	best: 0.7122445 (6)	total: 57.2ms	remaining: 0us
#
# bestTest = 0.7122445127
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 3:	loss: 0.7122445	best: 0.7122445 (2)	total: 150ms	remaining: 224ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 8.54ms	remaining: 25.6ms
# 1:	test: 0.6946181	best: 0.6946181 (1)	total: 21.9ms	remaining: 21.9ms
# 2:	test: 0.7119256	best: 0.7119256 (2)	total: 36.6ms	remaining: 12.2ms
# 3:	test: 0.7110749	best: 0.7119256 (2)	total: 46.5ms	remaining: 0us
#
# bestTest = 0.7119256319
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 4:	loss: 0.7119256	best: 0.7122445 (2)	total: 198ms	remaining: 198ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 7.36ms	remaining: 118ms
# 1:	test: 0.7157739	best: 0.7157739 (1)	total: 17.6ms	remaining: 132ms
# 2:	test: 0.7126871	best: 0.7157739 (1)	total: 27.2ms	remaining: 127ms
# 3:	test: 0.7145073	best: 0.7157739 (1)	total: 36.8ms	remaining: 120ms
# 4:	test: 0.7034893	best: 0.7157739 (1)	total: 48.4ms	remaining: 116ms
# 5:	test: 0.7077253	best: 0.7157739 (1)	total: 56.2ms	remaining: 103ms
# 6:	test: 0.7022049	best: 0.7157739 (1)	total: 61.2ms	remaining: 87.4ms
# 7:	test: 0.7028312	best: 0.7157739 (1)	total: 71.1ms	remaining: 80ms
# 8:	test: 0.6960760	best: 0.7157739 (1)	total: 79.5ms	remaining: 70.7ms
# 9:	test: 0.6898769	best: 0.7157739 (1)	total: 87.3ms	remaining: 61.1ms
# 10:	test: 0.6866180	best: 0.7157739 (1)	total: 94.9ms	remaining: 51.8ms
# 11:	test: 0.6865593	best: 0.7157739 (1)	total: 106ms	remaining: 44.3ms
# 12:	test: 0.6866830	best: 0.7157739 (1)	total: 115ms	remaining: 35.4ms
# 13:	test: 0.6839228	best: 0.7157739 (1)	total: 125ms	remaining: 26.7ms
# 14:	test: 0.6883323	best: 0.7157739 (1)	total: 132ms	remaining: 17.6ms
# 15:	test: 0.6865210	best: 0.7157739 (1)	total: 141ms	remaining: 8.8ms
# 16:	test: 0.6770911	best: 0.7157739 (1)	total: 148ms	remaining: 0us
#
# bestTest = 0.7157738854
# bestIteration = 1
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 5:	loss: 0.7157739	best: 0.7157739 (5)	total: 350ms	remaining: 233ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 2.13ms	remaining: 14.9ms
# 1:	test: 0.7125328	best: 0.7125328 (1)	total: 11.5ms	remaining: 34.5ms
# 2:	test: 0.7072904	best: 0.7125328 (1)	total: 20.3ms	remaining: 33.8ms
# 3:	test: 0.7119333	best: 0.7125328 (1)	total: 31.3ms	remaining: 31.3ms
# 4:	test: 0.7174729	best: 0.7174729 (4)	total: 42.6ms	remaining: 25.6ms
# 5:	test: 0.7146744	best: 0.7174729 (4)	total: 54.5ms	remaining: 18.2ms
# 6:	test: 0.7164435	best: 0.7174729 (4)	total: 61.9ms	remaining: 8.85ms
# 7:	test: 0.7095519	best: 0.7174729 (4)	total: 71.5ms	remaining: 0us
#
# bestTest = 0.7174728824
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 6:	loss: 0.7174729	best: 0.7174729 (6)	total: 423ms	remaining: 181ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 2.47ms	remaining: 29.6ms
# 1:	test: 0.6775975	best: 0.6775975 (1)	total: 5.42ms	remaining: 29.8ms
# 2:	test: 0.7064855	best: 0.7064855 (2)	total: 13.4ms	remaining: 44.5ms
# 3:	test: 0.7051590	best: 0.7064855 (2)	total: 17ms	remaining: 38.2ms
# 4:	test: 0.7084384	best: 0.7084384 (4)	total: 67.4ms	remaining: 108ms
# 5:	test: 0.7116744	best: 0.7116744 (5)	total: 116ms	remaining: 135ms
# 6:	test: 0.7179665	best: 0.7179665 (6)	total: 167ms	remaining: 143ms
# 7:	test: 0.7160494	best: 0.7179665 (6)	total: 222ms	remaining: 138ms
# 8:	test: 0.7154525	best: 0.7179665 (6)	total: 232ms	remaining: 103ms
# 9:	test: 0.7171068	best: 0.7179665 (6)	total: 284ms	remaining: 85.1ms
# 10:	test: 0.7169678	best: 0.7179665 (6)	total: 287ms	remaining: 52.2ms
# 11:	test: 0.7181808	best: 0.7181808 (11)	total: 294ms	remaining: 24.5ms
# 12:	test: 0.7170392	best: 0.7181808 (11)	total: 343ms	remaining: 0us
#
# bestTest = 0.7181807978
# bestIteration = 11
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 7:	loss: 0.7181808	best: 0.7181808 (7)	total: 769ms	remaining: 192ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 1.47ms	remaining: 5.88ms
# 1:	test: 0.7040914	best: 0.7040914 (1)	total: 103ms	remaining: 155ms
# 2:	test: 0.7042125	best: 0.7042125 (2)	total: 208ms	remaining: 139ms
# 3:	test: 0.7067164	best: 0.7067164 (3)	total: 316ms	remaining: 79ms
# 4:	test: 0.7063057	best: 0.7067164 (3)	total: 419ms	remaining: 0us
#
# bestTest = 0.7067163951
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 8:	loss: 0.7067164	best: 0.7181808 (7)	total: 1.19s	remaining: 132ms
# Estimating final quality...
# Training on fold [0/5]
# 0:	test: 0.7461366	best: 0.7461366 (0)	total: 51.7ms	remaining: 621ms
# 1:	test: 0.7433615	best: 0.7461366 (0)	total: 104ms	remaining: 574ms
# 2:	test: 0.7406848	best: 0.7461366 (0)	total: 161ms	remaining: 538ms
# 3:	test: 0.7402658	best: 0.7461366 (0)	total: 167ms	remaining: 376ms
# 4:	test: 0.7416702	best: 0.7461366 (0)	total: 217ms	remaining: 348ms
# 5:	test: 0.7398392	best: 0.7461366 (0)	total: 270ms	remaining: 315ms
# 6:	test: 0.7424535	best: 0.7461366 (0)	total: 286ms	remaining: 245ms
# 7:	test: 0.7414070	best: 0.7461366 (0)	total: 343ms	remaining: 214ms
# 8:	test: 0.7422813	best: 0.7461366 (0)	total: 400ms	remaining: 178ms
# 9:	test: 0.7421803	best: 0.7461366 (0)	total: 406ms	remaining: 122ms
# 10:	test: 0.7421803	best: 0.7461366 (0)	total: 410ms	remaining: 74.5ms
# 11:	test: 0.7432866	best: 0.7461366 (0)	total: 465ms	remaining: 38.8ms
# 12:	test: 0.7450465	best: 0.7461366 (0)	total: 478ms	remaining: 0us
#
# bestTest = 0.7461366148
# bestIteration = 0
#
# Training on fold [1/5]
# 0:	test: 0.7339347	best: 0.7339347 (0)	total: 74.6ms	remaining: 895ms
# 1:	test: 0.7397107	best: 0.7397107 (1)	total: 128ms	remaining: 705ms
# 2:	test: 0.7407821	best: 0.7407821 (2)	total: 179ms	remaining: 597ms
# 3:	test: 0.7409380	best: 0.7409380 (3)	total: 184ms	remaining: 415ms
# 4:	test: 0.7402308	best: 0.7409380 (3)	total: 194ms	remaining: 310ms
# 5:	test: 0.7422364	best: 0.7422364 (5)	total: 252ms	remaining: 294ms
# 6:	test: 0.7419645	best: 0.7422364 (5)	total: 305ms	remaining: 262ms
# 7:	test: 0.7443717	best: 0.7443717 (7)	total: 360ms	remaining: 225ms
# 8:	test: 0.7463923	best: 0.7463923 (8)	total: 372ms	remaining: 166ms
# 9:	test: 0.7430846	best: 0.7463923 (8)	total: 430ms	remaining: 129ms
# 10:	test: 0.7415529	best: 0.7463923 (8)	total: 434ms	remaining: 78.9ms
# 11:	test: 0.7422252	best: 0.7463923 (8)	total: 493ms	remaining: 41.1ms
# 12:	test: 0.7419134	best: 0.7463923 (8)	total: 544ms	remaining: 0us
#
# bestTest = 0.7463923029
# bestIteration = 8
#
# Training on fold [2/5]
# 0:	test: 0.7128585	best: 0.7128585 (0)	total: 69.4ms	remaining: 833ms
# 1:	test: 0.7160190	best: 0.7160190 (1)	total: 124ms	remaining: 682ms
# 2:	test: 0.7166838	best: 0.7166838 (2)	total: 180ms	remaining: 599ms
# 3:	test: 0.7149152	best: 0.7166838 (2)	total: 187ms	remaining: 421ms
# 4:	test: 0.7160415	best: 0.7166838 (2)	total: 201ms	remaining: 321ms
# 5:	test: 0.7188503	best: 0.7188503 (5)	total: 260ms	remaining: 304ms
# 6:	test: 0.7165117	best: 0.7188503 (5)	total: 312ms	remaining: 268ms
# 7:	test: 0.7193068	best: 0.7193068 (7)	total: 368ms	remaining: 230ms
# 8:	test: 0.7163558	best: 0.7193068 (7)	total: 420ms	remaining: 187ms
# 9:	test: 0.7163483	best: 0.7193068 (7)	total: 479ms	remaining: 144ms
# 10:	test: 0.7153094	best: 0.7193068 (7)	total: 531ms	remaining: 96.6ms
# 11:	test: 0.7149377	best: 0.7193068 (7)	total: 586ms	remaining: 48.8ms
# 12:	test: 0.7165267	best: 0.7193068 (7)	total: 608ms	remaining: 0us
#
# bestTest = 0.7193068233
# bestIteration = 7
#
# Training on fold [3/5]
# 0:	test: 0.7037049	best: 0.7037049 (0)	total: 57.3ms	remaining: 688ms
# 1:	test: 0.7070712	best: 0.7070712 (1)	total: 111ms	remaining: 611ms
# 2:	test: 0.7137079	best: 0.7137079 (2)	total: 168ms	remaining: 561ms
# 3:	test: 0.7152283	best: 0.7152283 (3)	total: 180ms	remaining: 405ms
# 4:	test: 0.7138164	best: 0.7152283 (3)	total: 234ms	remaining: 374ms
# 5:	test: 0.7140621	best: 0.7152283 (3)	total: 292ms	remaining: 341ms
# 6:	test: 0.7143003	best: 0.7152283 (3)	total: 344ms	remaining: 295ms
# 7:	test: 0.7121114	best: 0.7152283 (3)	total: 401ms	remaining: 251ms
# 8:	test: 0.7126140	best: 0.7152283 (3)	total: 459ms	remaining: 204ms
# 9:	test: 0.7114217	best: 0.7152283 (3)	total: 475ms	remaining: 142ms
# 10:	test: 0.7112508	best: 0.7152283 (3)	total: 494ms	remaining: 89.9ms
# 11:	test: 0.7095982	best: 0.7152283 (3)	total: 547ms	remaining: 45.6ms
# 12:	test: 0.7089296	best: 0.7152283 (3)	total: 601ms	remaining: 0us
#
# bestTest = 0.7152282858
# bestIteration = 3
#
# Training on fold [4/5]
# 0:	test: 0.6962899	best: 0.6962899 (0)	total: 12ms	remaining: 144ms
# 1:	test: 0.7093961	best: 0.7093961 (1)	total: 24.7ms	remaining: 136ms
# 2:	test: 0.7106097	best: 0.7106097 (2)	total: 75ms	remaining: 250ms
# 3:	test: 0.7106346	best: 0.7106346 (3)	total: 90.7ms	remaining: 204ms
# 4:	test: 0.7107369	best: 0.7107369 (4)	total: 94.3ms	remaining: 151ms
# 5:	test: 0.7137478	best: 0.7137478 (5)	total: 102ms	remaining: 119ms
# 6:	test: 0.7152557	best: 0.7152557 (6)	total: 159ms	remaining: 136ms
# 7:	test: 0.7187780	best: 0.7187780 (7)	total: 216ms	remaining: 135ms
# 8:	test: 0.7159654	best: 0.7187780 (7)	total: 271ms	remaining: 121ms
# 9:	test: 0.7170655	best: 0.7187780 (7)	total: 329ms	remaining: 98.6ms
# 10:	test: 0.7183427	best: 0.7187780 (7)	total: 388ms	remaining: 70.5ms
# 11:	test: 0.7189364	best: 0.7189364 (11)	total: 445ms	remaining: 37.1ms
# 12:	test: 0.7168822	best: 0.7189364 (11)	total: 504ms	remaining: 0us
#
# bestTest = 0.7189363873
# bestIteration = 11
#
# 14 13 0.2

# %%
model_catboost = CatBoostClassifier(loss_function='Logloss', eval_metric='AUC', random_seed=12345)

grid = {'max_depth':[14],
        'learning_rate':np.arange(0.1,0.3, 1e-6),
        'iterations':[13]
       }

random_search_result = model_catboost.randomized_search(grid, 
                                       X=cv_dataset,
                                       cv=5,
                                       plot=False)

depth_catboost = random_search_result['params']['depth']
learning_rate_catboost = random_search_result['params']['learning_rate']
iterations_catboost = random_search_result['params']['iterations']


print(depth_catboost, learning_rate_catboost, iterations_catboost)
# Out:
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 1.39ms	remaining: 16.7ms
# 1:	test: 0.6773245	best: 0.6773245 (1)	total: 4.02ms	remaining: 22.1ms
# 2:	test: 0.7060518	best: 0.7060518 (2)	total: 8.23ms	remaining: 27.5ms
# 3:	test: 0.7032304	best: 0.7060518 (2)	total: 9.84ms	remaining: 22.1ms
# 4:	test: 0.7096526	best: 0.7096526 (4)	total: 29.7ms	remaining: 47.5ms
# 5:	test: 0.7100646	best: 0.7100646 (5)	total: 33.1ms	remaining: 38.6ms
# 6:	test: 0.7113631	best: 0.7113631 (6)	total: 80.4ms	remaining: 68.9ms
# 7:	test: 0.7120366	best: 0.7120366 (7)	total: 84.5ms	remaining: 52.8ms
# 8:	test: 0.7119371	best: 0.7120366 (7)	total: 132ms	remaining: 58.7ms
# 9:	test: 0.7147956	best: 0.7147956 (9)	total: 181ms	remaining: 54.4ms
# 10:	test: 0.7139282	best: 0.7147956 (9)	total: 232ms	remaining: 42.2ms
# 11:	test: 0.7146183	best: 0.7147956 (9)	total: 243ms	remaining: 20.2ms
# 12:	test: 0.7149627	best: 0.7149627 (12)	total: 296ms	remaining: 0us
#
# bestTest = 0.7149626527
# bestIteration = 12
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 0:	loss: 0.7149627	best: 0.7149627 (0)	total: 302ms	remaining: 2.71s
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 4.68ms	remaining: 56.1ms
# 1:	test: 0.6773245	best: 0.6773245 (1)	total: 13.3ms	remaining: 73.1ms
# 2:	test: 0.7060621	best: 0.7060621 (2)	total: 25.6ms	remaining: 85.2ms
# 3:	test: 0.7034523	best: 0.7060621 (2)	total: 31.5ms	remaining: 70.9ms
# 4:	test: 0.7100302	best: 0.7100302 (4)	total: 56.3ms	remaining: 90.1ms
# 5:	test: 0.7087215	best: 0.7100302 (4)	total: 64.8ms	remaining: 75.6ms
# 6:	test: 0.7118517	best: 0.7118517 (6)	total: 76.8ms	remaining: 65.9ms
# 7:	test: 0.7130787	best: 0.7130787 (7)	total: 78.9ms	remaining: 49.3ms
# 8:	test: 0.7149206	best: 0.7149206 (8)	total: 128ms	remaining: 57ms
# 9:	test: 0.7149499	best: 0.7149499 (9)	total: 181ms	remaining: 54.4ms
# 10:	test: 0.7139512	best: 0.7149499 (9)	total: 236ms	remaining: 42.8ms
# 11:	test: 0.7139116	best: 0.7149499 (9)	total: 289ms	remaining: 24.1ms
# 12:	test: 0.7124856	best: 0.7149499 (9)	total: 344ms	remaining: 0us
#
# bestTest = 0.7149498974
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 1:	loss: 0.7149499	best: 0.7149627 (0)	total: 649ms	remaining: 2.59s
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 5.46ms	remaining: 65.6ms
# 1:	test: 0.6773245	best: 0.6773245 (1)	total: 7.98ms	remaining: 43.9ms
# 2:	test: 0.7060621	best: 0.7060621 (2)	total: 19.9ms	remaining: 66.5ms
# 3:	test: 0.7039957	best: 0.7060621 (2)	total: 27.9ms	remaining: 62.8ms
# 4:	test: 0.7082521	best: 0.7082521 (4)	total: 81.5ms	remaining: 130ms
# 5:	test: 0.7101590	best: 0.7101590 (5)	total: 95.2ms	remaining: 111ms
# 6:	test: 0.7104907	best: 0.7104907 (6)	total: 149ms	remaining: 128ms
# 7:	test: 0.7115238	best: 0.7115238 (7)	total: 204ms	remaining: 128ms
# 8:	test: 0.7142917	best: 0.7142917 (8)	total: 261ms	remaining: 116ms
# 9:	test: 0.7151718	best: 0.7151718 (9)	total: 321ms	remaining: 96.2ms
# 10:	test: 0.7153402	best: 0.7153402 (10)	total: 329ms	remaining: 59.8ms
# 11:	test: 0.7159129	best: 0.7159129 (11)	total: 340ms	remaining: 28.3ms
# 12:	test: 0.7174180	best: 0.7174180 (12)	total: 400ms	remaining: 0us
#
# bestTest = 0.7174180349
# bestIteration = 12
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 2:	loss: 0.7174180	best: 0.7174180 (2)	total: 1.05s	remaining: 2.45s
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 6.88ms	remaining: 82.6ms
# 1:	test: 0.6773245	best: 0.6773245 (1)	total: 16.7ms	remaining: 91.6ms
# 2:	test: 0.7060621	best: 0.7060621 (2)	total: 29.4ms	remaining: 98ms
# 3:	test: 0.7047738	best: 0.7060621 (2)	total: 36.9ms	remaining: 83ms
# 4:	test: 0.7082878	best: 0.7082878 (4)	total: 96.1ms	remaining: 154ms
# 5:	test: 0.7102075	best: 0.7102075 (5)	total: 109ms	remaining: 128ms
# 6:	test: 0.7104983	best: 0.7104983 (6)	total: 166ms	remaining: 142ms
# 7:	test: 0.7115545	best: 0.7115545 (7)	total: 220ms	remaining: 137ms
# 8:	test: 0.7144703	best: 0.7144703 (8)	total: 276ms	remaining: 123ms
# 9:	test: 0.7143058	best: 0.7144703 (8)	total: 333ms	remaining: 99.9ms
# 10:	test: 0.7139359	best: 0.7144703 (8)	total: 343ms	remaining: 62.4ms
# 11:	test: 0.7152739	best: 0.7152739 (11)	total: 358ms	remaining: 29.8ms
# 12:	test: 0.7183198	best: 0.7183198 (12)	total: 416ms	remaining: 0us
#
# bestTest = 0.7183198298
# bestIteration = 12
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 3:	loss: 0.7183198	best: 0.7183198 (3)	total: 1.47s	remaining: 2.21s
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 8.21ms	remaining: 98.5ms
# 1:	test: 0.6775975	best: 0.6775975 (1)	total: 15ms	remaining: 82.3ms
# 2:	test: 0.7061973	best: 0.7061973 (2)	total: 22.9ms	remaining: 76.2ms
# 3:	test: 0.7048452	best: 0.7061973 (2)	total: 31.5ms	remaining: 71ms
# 4:	test: 0.7099664	best: 0.7099664 (4)	total: 144ms	remaining: 230ms
# 5:	test: 0.7089026	best: 0.7099664 (4)	total: 161ms	remaining: 187ms
# 6:	test: 0.7121833	best: 0.7121833 (6)	total: 175ms	remaining: 150ms
# 7:	test: 0.7130966	best: 0.7130966 (7)	total: 180ms	remaining: 113ms
# 8:	test: 0.7137228	best: 0.7137228 (8)	total: 241ms	remaining: 107ms
# 9:	test: 0.7141272	best: 0.7141272 (9)	total: 298ms	remaining: 89.4ms
# 10:	test: 0.7149461	best: 0.7149461 (10)	total: 355ms	remaining: 64.6ms
# 11:	test: 0.7145685	best: 0.7149461 (10)	total: 413ms	remaining: 34.4ms
# 12:	test: 0.7118695	best: 0.7149461 (10)	total: 466ms	remaining: 0us
#
# bestTest = 0.7149460709
# bestIteration = 10
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 4:	loss: 0.7149461	best: 0.7183198 (3)	total: 1.94s	remaining: 1.94s
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 8.51ms	remaining: 102ms
# 1:	test: 0.6775975	best: 0.6775975 (1)	total: 18.6ms	remaining: 103ms
# 2:	test: 0.7061973	best: 0.7061973 (2)	total: 29.3ms	remaining: 97.5ms
# 3:	test: 0.7048835	best: 0.7061973 (2)	total: 36.9ms	remaining: 83ms
# 4:	test: 0.7084332	best: 0.7084332 (4)	total: 93ms	remaining: 149ms
# 5:	test: 0.7101590	best: 0.7101590 (5)	total: 107ms	remaining: 125ms
# 6:	test: 0.7105519	best: 0.7105519 (6)	total: 163ms	remaining: 139ms
# 7:	test: 0.7117024	best: 0.7117024 (7)	total: 221ms	remaining: 138ms
# 8:	test: 0.7165035	best: 0.7165035 (8)	total: 283ms	remaining: 126ms
# 9:	test: 0.7182624	best: 0.7182624 (9)	total: 339ms	remaining: 102ms
# 10:	test: 0.7180992	best: 0.7182624 (9)	total: 346ms	remaining: 62.8ms
# 11:	test: 0.7185481	best: 0.7185481 (11)	total: 358ms	remaining: 29.8ms
# 12:	test: 0.7214614	best: 0.7214614 (12)	total: 424ms	remaining: 0us
#
# bestTest = 0.7214614435
# bestIteration = 12
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 5:	loss: 0.7214614	best: 0.7214614 (5)	total: 2.37s	remaining: 1.58s
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 5.96ms	remaining: 71.6ms
# 1:	test: 0.6775975	best: 0.6775975 (1)	total: 18.9ms	remaining: 104ms
# 2:	test: 0.7065289	best: 0.7065289 (2)	total: 37ms	remaining: 123ms
# 3:	test: 0.7049064	best: 0.7065289 (2)	total: 46.3ms	remaining: 104ms
# 4:	test: 0.7101093	best: 0.7101093 (4)	total: 85.5ms	remaining: 137ms
# 5:	test: 0.7090812	best: 0.7101093 (4)	total: 90.6ms	remaining: 106ms
# 6:	test: 0.7123440	best: 0.7123440 (6)	total: 108ms	remaining: 92.2ms
# 7:	test: 0.7134588	best: 0.7134588 (7)	total: 116ms	remaining: 72.3ms
# 8:	test: 0.7151897	best: 0.7151897 (8)	total: 169ms	remaining: 75.3ms
# 9:	test: 0.7175775	best: 0.7175775 (9)	total: 225ms	remaining: 67.5ms
# 10:	test: 0.7165124	best: 0.7175775 (9)	total: 280ms	remaining: 51ms
# 11:	test: 0.7157777	best: 0.7175775 (9)	total: 336ms	remaining: 28ms
# 12:	test: 0.7154295	best: 0.7175775 (9)	total: 395ms	remaining: 0us
#
# bestTest = 0.7175774753
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 6:	loss: 0.7175775	best: 0.7214614 (5)	total: 2.76s	remaining: 1.18s
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 6.04ms	remaining: 72.5ms
# 1:	test: 0.6959561	best: 0.6959561 (1)	total: 66ms	remaining: 363ms
# 2:	test: 0.7040352	best: 0.7040352 (2)	total: 89.5ms	remaining: 298ms
# 3:	test: 0.7088197	best: 0.7088197 (3)	total: 145ms	remaining: 325ms
# 4:	test: 0.7077598	best: 0.7088197 (3)	total: 154ms	remaining: 246ms
# 5:	test: 0.7094843	best: 0.7094843 (5)	total: 211ms	remaining: 246ms
# 6:	test: 0.7077177	best: 0.7094843 (5)	total: 266ms	remaining: 228ms
# 7:	test: 0.7055059	best: 0.7094843 (5)	total: 324ms	remaining: 202ms
# 8:	test: 0.7064881	best: 0.7094843 (5)	total: 374ms	remaining: 166ms
# 9:	test: 0.7067636	best: 0.7094843 (5)	total: 390ms	remaining: 117ms
# 10:	test: 0.7071705	best: 0.7094843 (5)	total: 447ms	remaining: 81.3ms
# 11:	test: 0.7067865	best: 0.7094843 (5)	total: 504ms	remaining: 42ms
# 12:	test: 0.7075748	best: 0.7094843 (5)	total: 561ms	remaining: 0us
#
# bestTest = 0.7094842805
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 7:	loss: 0.7094843	best: 0.7214614 (5)	total: 3.33s	remaining: 832ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 4.43ms	remaining: 53.2ms
# 1:	test: 0.6957061	best: 0.6957061 (1)	total: 58.5ms	remaining: 322ms
# 2:	test: 0.7039204	best: 0.7039204 (2)	total: 81.9ms	remaining: 273ms
# 3:	test: 0.7086871	best: 0.7086871 (3)	total: 131ms	remaining: 295ms
# 4:	test: 0.7084868	best: 0.7086871 (3)	total: 145ms	remaining: 231ms
# 5:	test: 0.7107037	best: 0.7107037 (5)	total: 199ms	remaining: 232ms
# 6:	test: 0.7076182	best: 0.7107037 (5)	total: 260ms	remaining: 222ms
# 7:	test: 0.7068031	best: 0.7107037 (5)	total: 276ms	remaining: 172ms
# 8:	test: 0.7090162	best: 0.7107037 (5)	total: 330ms	remaining: 147ms
# 9:	test: 0.7088669	best: 0.7107037 (5)	total: 360ms	remaining: 108ms
# 10:	test: 0.7069141	best: 0.7107037 (5)	total: 418ms	remaining: 76ms
# 11:	test: 0.7052674	best: 0.7107037 (5)	total: 476ms	remaining: 39.6ms
# 12:	test: 0.7046564	best: 0.7107037 (5)	total: 533ms	remaining: 0us
#
# bestTest = 0.7107036806
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 8:	loss: 0.7107037	best: 0.7214614 (5)	total: 3.86s	remaining: 429ms
# 0:	test: 0.6270651	best: 0.6270651 (0)	total: 7.99ms	remaining: 95.9ms
# 1:	test: 0.6957112	best: 0.6957112 (1)	total: 64.3ms	remaining: 354ms
# 2:	test: 0.7039204	best: 0.7039204 (2)	total: 84.6ms	remaining: 282ms
# 3:	test: 0.7086998	best: 0.7086998 (3)	total: 141ms	remaining: 317ms
# 4:	test: 0.7085072	best: 0.7086998 (3)	total: 153ms	remaining: 244ms
# 5:	test: 0.7107164	best: 0.7107164 (5)	total: 210ms	remaining: 245ms
# 6:	test: 0.7075978	best: 0.7107164 (5)	total: 268ms	remaining: 229ms
# 7:	test: 0.7067904	best: 0.7107164 (5)	total: 285ms	remaining: 178ms
# 8:	test: 0.7090034	best: 0.7107164 (5)	total: 341ms	remaining: 152ms
# 9:	test: 0.7088440	best: 0.7107164 (5)	total: 373ms	remaining: 112ms
# 10:	test: 0.7068886	best: 0.7107164 (5)	total: 432ms	remaining: 78.6ms
# 11:	test: 0.7052291	best: 0.7107164 (5)	total: 490ms	remaining: 40.9ms
# 12:	test: 0.7047100	best: 0.7107164 (5)	total: 554ms	remaining: 0us
#
# bestTest = 0.7107164359
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 9:	loss: 0.7107164	best: 0.7214614 (5)	total: 4.42s	remaining: 0us
# Estimating final quality...
# Training on fold [0/5]
# 0:	test: 0.7461366	best: 0.7461366 (0)	total: 53.1ms	remaining: 637ms
# 1:	test: 0.7464260	best: 0.7464260 (1)	total: 107ms	remaining: 588ms
# 2:	test: 0.7434051	best: 0.7464260 (1)	total: 158ms	remaining: 527ms
# 3:	test: 0.7436321	best: 0.7464260 (1)	total: 164ms	remaining: 370ms
# 4:	test: 0.7454381	best: 0.7464260 (1)	total: 224ms	remaining: 359ms
# 5:	test: 0.7472093	best: 0.7472093 (5)	total: 310ms	remaining: 361ms
# 6:	test: 0.7471918	best: 0.7472093 (5)	total: 325ms	remaining: 279ms
# 7:	test: 0.7468737	best: 0.7472093 (5)	total: 379ms	remaining: 237ms
# 8:	test: 0.7464297	best: 0.7472093 (5)	total: 451ms	remaining: 200ms
# 9:	test: 0.7461765	best: 0.7472093 (5)	total: 456ms	remaining: 137ms
# 10:	test: 0.7461740	best: 0.7472093 (5)	total: 462ms	remaining: 83.9ms
# 11:	test: 0.7470571	best: 0.7472093 (5)	total: 473ms	remaining: 39.5ms
# 12:	test: 0.7459084	best: 0.7472093 (5)	total: 525ms	remaining: 0us
#
# bestTest = 0.7472092577
# bestIteration = 5
#
# Training on fold [1/5]
# 0:	test: 0.7340332	best: 0.7340332 (0)	total: 51.5ms	remaining: 618ms
# 1:	test: 0.7395885	best: 0.7395885 (1)	total: 103ms	remaining: 568ms
# 2:	test: 0.7449368	best: 0.7449368 (2)	total: 154ms	remaining: 512ms
# 3:	test: 0.7430858	best: 0.7449368 (2)	total: 159ms	remaining: 358ms
# 4:	test: 0.7447160	best: 0.7449368 (2)	total: 163ms	remaining: 261ms
# 5:	test: 0.7472030	best: 0.7472030 (5)	total: 215ms	remaining: 251ms
# 6:	test: 0.7467490	best: 0.7472030 (5)	total: 271ms	remaining: 233ms
# 7:	test: 0.7459483	best: 0.7472030 (5)	total: 297ms	remaining: 186ms
# 8:	test: 0.7438379	best: 0.7472030 (5)	total: 351ms	remaining: 156ms
# 9:	test: 0.7455192	best: 0.7472030 (5)	total: 405ms	remaining: 121ms
# 10:	test: 0.7448532	best: 0.7472030 (5)	total: 460ms	remaining: 83.6ms
# 11:	test: 0.7432704	best: 0.7472030 (5)	total: 516ms	remaining: 43ms
# 12:	test: 0.7435710	best: 0.7472030 (5)	total: 569ms	remaining: 0us
#
# bestTest = 0.7472030214
# bestIteration = 5
#
# Training on fold [2/5]
# 0:	test: 0.7128610	best: 0.7128610 (0)	total: 57.5ms	remaining: 690ms
# 1:	test: 0.7171590	best: 0.7171590 (1)	total: 115ms	remaining: 630ms
# 2:	test: 0.7148578	best: 0.7171590 (1)	total: 171ms	remaining: 571ms
# 3:	test: 0.7132289	best: 0.7171590 (1)	total: 178ms	remaining: 400ms
# 4:	test: 0.7123259	best: 0.7171590 (1)	total: 185ms	remaining: 296ms
# 5:	test: 0.7150424	best: 0.7171590 (1)	total: 206ms	remaining: 241ms
# 6:	test: 0.7148815	best: 0.7171590 (1)	total: 217ms	remaining: 186ms
# 7:	test: 0.7171565	best: 0.7171590 (1)	total: 276ms	remaining: 173ms
# 8:	test: 0.7175033	best: 0.7175033 (8)	total: 286ms	remaining: 127ms
# 9:	test: 0.7162161	best: 0.7175033 (8)	total: 293ms	remaining: 87.8ms
# 10:	test: 0.7153979	best: 0.7175033 (8)	total: 347ms	remaining: 63ms
# 11:	test: 0.7160328	best: 0.7175033 (8)	total: 403ms	remaining: 33.6ms
# 12:	test: 0.7178014	best: 0.7178014 (12)	total: 455ms	remaining: 0us
#
# bestTest = 0.7178013815
# bestIteration = 12
#
# Training on fold [3/5]
# 0:	test: 0.7037049	best: 0.7037049 (0)	total: 51ms	remaining: 612ms
# 1:	test: 0.7065212	best: 0.7065212 (1)	total: 109ms	remaining: 599ms
# 2:	test: 0.7114491	best: 0.7114491 (2)	total: 166ms	remaining: 555ms
# 3:	test: 0.7138501	best: 0.7138501 (3)	total: 173ms	remaining: 390ms
# 4:	test: 0.7140384	best: 0.7140384 (4)	total: 224ms	remaining: 359ms
# 5:	test: 0.7147419	best: 0.7147419 (5)	total: 282ms	remaining: 330ms
# 6:	test: 0.7166364	best: 0.7166364 (6)	total: 300ms	remaining: 257ms
# 7:	test: 0.7152507	best: 0.7166364 (6)	total: 358ms	remaining: 224ms
# 8:	test: 0.7151934	best: 0.7166364 (6)	total: 414ms	remaining: 184ms
# 9:	test: 0.7151085	best: 0.7166364 (6)	total: 444ms	remaining: 133ms
# 10:	test: 0.7138887	best: 0.7166364 (6)	total: 464ms	remaining: 84.3ms
# 11:	test: 0.7138962	best: 0.7166364 (6)	total: 522ms	remaining: 43.5ms
# 12:	test: 0.7143016	best: 0.7166364 (6)	total: 578ms	remaining: 0us
#
# bestTest = 0.7166364414
# bestIteration = 6
#
# Training on fold [4/5]
# 0:	test: 0.6962899	best: 0.6962899 (0)	total: 14.2ms	remaining: 170ms
# 1:	test: 0.7094659	best: 0.7094659 (1)	total: 33.9ms	remaining: 186ms
# 2:	test: 0.7138862	best: 0.7138862 (2)	total: 96ms	remaining: 320ms
# 3:	test: 0.7121076	best: 0.7138862 (2)	total: 114ms	remaining: 257ms
# 4:	test: 0.7120964	best: 0.7138862 (2)	total: 120ms	remaining: 191ms
# 5:	test: 0.7134335	best: 0.7138862 (2)	total: 132ms	remaining: 154ms
# 6:	test: 0.7153368	best: 0.7153368 (6)	total: 191ms	remaining: 164ms
# 7:	test: 0.7182117	best: 0.7182117 (7)	total: 251ms	remaining: 157ms
# 8:	test: 0.7176330	best: 0.7182117 (7)	total: 257ms	remaining: 114ms
# 9:	test: 0.7168497	best: 0.7182117 (7)	total: 269ms	remaining: 80.6ms
# 10:	test: 0.7195388	best: 0.7195388 (10)	total: 327ms	remaining: 59.5ms
# 11:	test: 0.7195076	best: 0.7195388 (10)	total: 385ms	remaining: 32.1ms
# 12:	test: 0.7201774	best: 0.7201774 (12)	total: 449ms	remaining: 0us
#
# bestTest = 0.7201774101
# bestIteration = 12
#
# 14 0.14234300000004235 13

# %%
from catboost.utils import get_roc_curve
import sklearn
from sklearn import metrics

model_catboost = CatBoostClassifier(loss_function='Logloss', 
                                    eval_metric='AUC', 
                                    random_seed=12345,
                                    iterations= iterations_catboost,
                                    depth= depth_catboost,
                                    learning_rate= learning_rate_catboost
                                    )


model_catboost.fit(
    features_train_scaler,target_train,
    cat_features=None,
    verbose=False
)


eval_pool = Pool(features_test_scaler, target_test, cat_features=None)
curve = get_roc_curve(model_catboost, eval_pool)
(fpr, tpr, thresholds)=curve
roc_auc=auc(fpr, tpr)

# %%
plt.figure(figsize=(16, 8))
lw=2

plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc, alpha=0.5)

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--', alpha=0.5)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid(True)
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('Receiver operating characteristic', fontsize=20)
plt.legend(loc="lower right", fontsize=16)
plt.show()

# %% [markdown]
# [К оглавлению](#root)

# %% [markdown]
# #### Модель 2 <a id='4.1.2'>

# %% [markdown]
# ну а теперь построим что-нибудь попроще, например логистическую регрессию. Поскольку время уже поджимает - возьмем ее из <a href='https://github.com/goshabaturin/Data_Science_and_Analysis/blob/master/Yandex.Praktikum/2%20-%20%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%B2%20%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D0%BE%D0%B5%20%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D0%B5/2.2%20%D0%9F%D1%80%D0%BE%D0%B3%D0%BD%D0%BE%D0%B7%20%D0%BE%D1%82%D1%82%D0%BE%D0%BA%D0%B0%20%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2%20%D0%B8%D0%B7%20%D0%B1%D0%B0%D0%BD%D0%BA%D0%B0/%D0%9F%D1%80%D0%BE%D0%B3%D0%BD%D0%BE%D0%B7%20%D0%BE%D1%82%D1%82%D0%BE%D0%BA%D0%B0%20%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2%20%D0%B8%D0%B7%20%D0%B1%D0%B0%D0%BD%D0%BA%D0%B0.ipynb'>вот этого своего же материала </a> (там как раз тоже дисбаланс классов).

# %%
def upsample(features, target, repeat):
    #разделим выборку на отрицательные и положительные объекты
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    
    # скопируем несколько раз положительные объекты
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    # перемешаем строки, так чтоб у нас не было несколько одинаковых блоков, но так чтоб были одинаковые строки
    # по сути, если представить в виде строк, то мы перемешиваем строки таблицы, но не трогаем столбцы
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled




features_train_scaler_upsampled, target_train_scaler_upsampled = upsample(pd.DataFrame(features_train_scaler), target_train.reset_index(drop=True), 5)


model_logistic = LogisticRegressionCV(cv = 5, random_state = 12345 )


model_logistic.fit(features_train_scaler_upsampled,target_train_scaler_upsampled)
predictions_test = model_logistic.predict(features_test_scaler)

res = pd.DataFrame(predictions_test).rename(columns={0:'pred'}).join(target_test.reset_index(drop=True))

fpr_1, tpr_1, thresholds_1 = roc_auc(res.pred, res.target)

fig, ax = plt.subplots(figsize=(20,7))
fig.suptitle('ROC_AUC')
ax.plot(tpr_1, fpr_1, label='model_1')
ax.plot([[0],[1]],[[0],[1]], label='random_model')
plt.legend()
plt.show()

# %% [markdown]
# [К оглавлению](#root)

# %% [markdown]
# #### Вывод <a id='4.1.3'>

# %% [markdown]
# Сравнивая 2 модели по метрике ROC-AUC можно сделать вывод, что модель построенная с помощью бустинга над случайным лесом - гораздо лучше предсказывает вероятность дефолта. Модель построенная с помощью логистической регрессии - работает даже хуже, чем случайное предсказание.

# %% [markdown]
# [К оглавлению](#root)
